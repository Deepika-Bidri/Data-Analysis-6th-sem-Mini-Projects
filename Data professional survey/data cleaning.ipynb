# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_profe = pd.read_excel("Data Professional Survey dataset.xlsx")

# %%
data_profe.head(10)
# Out:
#                   Unique ID      Email Date Taken (America/New_York)  \
# 0  62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1  62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2  62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3  62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4  62a33c91f3072dd892621e03  anonymous                     6/10/2022
# 5  62a33cb6cf25554317300177  anonymous                     6/10/2022
# 6  62a33cb72e54c9003e531c65  anonymous                     6/10/2022
# 7  62a33cd30f8c8599d5af0f8f  anonymous                     6/10/2022
# 8  62a33cd3cf255543173001d9  anonymous                     6/10/2022
# 9  62a33cd8bc6861bf3176c05f  anonymous                     6/10/2022
#
#   Time Taken (America/New_York)  Browser  OS  City  Country  Referrer  \
# 0                          8:38      NaN NaN   NaN      NaN       NaN
# ...

# %%
data_profe.dropna(axis=1,inplace=True)

# %%
data_profe.head(10)
# Out:
#                   Unique ID      Email Date Taken (America/New_York)  \
# 0  62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1  62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2  62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3  62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4  62a33c91f3072dd892621e03  anonymous                     6/10/2022
# 5  62a33cb6cf25554317300177  anonymous                     6/10/2022
# 6  62a33cb72e54c9003e531c65  anonymous                     6/10/2022
# 7  62a33cd30f8c8599d5af0f8f  anonymous                     6/10/2022
# 8  62a33cd3cf255543173001d9  anonymous                     6/10/2022
# 9  62a33cd8bc6861bf3176c05f  anonymous                     6/10/2022
#
#   Time Taken (America/New_York) Time Spent  \
# 0                          8:38    0:00:44
# 1                          8:40    0:01:30
# 2                          8:42    0:02:18
# ...

# %%
data_profe.shape
# Out:
# (630, 16)

# %%
data_profe["Q5 - Favorite Programming Language"].value_counts()
# Out:
# Q5 - Favorite Programming Language
# Python                                                                                                                                                                                                                                                   420
# R                                                                                                                                                                                                                                                        101
# Other:SQL                                                                                                                                                                                                                                                 27
# ...

# %%
data_profe["Q5 - Favorite Programming Language"].dropna()
# Out:
# 0      Python
# 1           R
# 2      Python
# 3           R
# 4           R
#         ...
# 625         R
# 626         R
# 627    Python
# 628    Python
# 629    Python
# Name: Q5 - Favorite Programming Language, Length: 630, dtype: object

# %%
data_profe.head(10)
# Out:
#                   Unique ID      Email Date Taken (America/New_York)  \
# 0  62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1  62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2  62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3  62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4  62a33c91f3072dd892621e03  anonymous                     6/10/2022
# 5  62a33cb6cf25554317300177  anonymous                     6/10/2022
# 6  62a33cb72e54c9003e531c65  anonymous                     6/10/2022
# 7  62a33cd30f8c8599d5af0f8f  anonymous                     6/10/2022
# 8  62a33cd3cf255543173001d9  anonymous                     6/10/2022
# 9  62a33cd8bc6861bf3176c05f  anonymous                     6/10/2022
#
#   Time Taken (America/New_York) Time Spent  \
# 0                          8:38    0:00:44
# 1                          8:40    0:01:30
# 2                          8:42    0:02:18
# ...
